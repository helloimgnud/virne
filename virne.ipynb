# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 1. Remove old project in Colab
# !rm -rf /content/virne

# 2. Clone specific branch
# !git clone -b dev_v2 https://github.com/helloimgnud/virne.git

# 3. Remove old project in Drive
# !rm -rf /content/drive/MyDrive/virne

# 4. Copy project to Drive
# !cp -r /content/virne /content/drive/MyDrive/

# 5. Enter project
# %cd /content/drive/MyDrive/virne
# Out:
# Cloning into 'virne'...
# remote: Enumerating objects: 1903, done.
# remote: Counting objects: 100% (576/576), done.
# remote: Compressing objects: 100% (261/261), done.
# remote: Total 1903 (delta 370), reused 353 (delta 314), pack-reused 1327 (from 1)
# Receiving objects: 100% (1903/1903), 4.81 MiB | 20.63 MiB/s, done.
# Resolving deltas: 100% (1149/1149), done.
# /content/drive/MyDrive/virne

# %%
# Restart runtime FIRST before running this CHATGPT

# Remove conflicting packages
# !pip uninstall -y torch torchvision torchaudio numpy scipy

# Stable NumPy
# !pip install numpy==1.26.4

# Torch
# !pip install torch==2.6.0 --index-url https://download.pytorch.org/whl/cu124

# PyG
# !pip install torch_geometric
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv \
    -f https://data.pyg.org/whl/torch-2.6.0+cu124.html

# RL / utilities
# !pip install gym==0.22.0 scipy==1.13.1
# !pip install pyyaml tqdm colorama hydra-core colorlog wandb ortools higher tensorboard

# Fix protobuf/fsspec
# !pip install protobuf==5.29.5 fsspec==2025.3.0
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Found existing installation: numpy 2.4.4
# Uninstalling numpy-2.4.4:
#   Successfully uninstalled numpy-2.4.4
# Found existing installation: scipy 1.17.1
# Uninstalling scipy-1.17.1:
#   Successfully uninstalled scipy-1.17.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 128.5 MB/s  0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc 5.28.4 requires scipy>=1.4.1, which is not installed.
# ...

# %%
# # 1. Upgrade pip GEMINI
# !pip install --upgrade pip

# # 2. Install basic dependencies (Colab already has numpy, pandas, matplotlib, scikit-learn, networkx)
# !pip install pyyaml tqdm colorama hydra-core colorlog wandb ortools higher tensorboard

# # 3. Install PyTorch 2.6.0 with CUDA 12.4
# !pip install torch==2.6.0 --index-url https://download.pytorch.org/whl/cu124 --force-reinstall

# # 4. Install PyTorch Geometric and specific C++ extensions matching torch 2.6.0 + cu124
# !pip install torch_geometric
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.6.0+cu124.html

# # 5. Install specific Gym and SciPy versions
# !pip install gym==0.22.0
# !pip install numpy==1.26.4 --force-reinstall
# !pip install --force-reinstall scipy

# %%
# # upgrade pip
# !pip install --upgrade pip

# # basic deps
# !pip install numpy pandas matplotlib networkx
# !pip install pyyaml tqdm colorama hydra-core colorlog wandb
# !pip install ortools scikit-learn

# # pytorch (colab already has CUDA)
# !pip install torch==2.6.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# # RL / graph libs
# !pip install tensorboard higher
# !pip install torch_geometric
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.6.0+cu124.html
# !pip install numpy
# # !pip install numpy==1.26.4

# %%
# other deps
# !pip install gym==0.22.0
# !pip install scipy --force-reinstall

# %%
# !python main.py \
#   experiment.seed=42 \
#   experiment.if_load_p_net=true \
#   experiment.if_load_v_nets=true \
#   p_net_setting.output.save_dir="/content/drive/MyDrive/virne_output/datasets_hard/p_net" \
#   v_sim_setting.output.save_dir="/content/drive/MyDrive/virne_output/datasets_hard/v_nets" \
#   solver.solver_name=pl_rank

# %%
# !python main.py \
# experiment.seed=42 \
# experiment.if_save_p_net=true \
#   experiment.if_save_v_nets=true \
#   p_net_setting.output.save_dir="/content/drive/MyDrive/virne_output/datasets_hard/p_net" \
#   v_sim_setting.output.save_dir="/content/drive/MyDrive/virne_output/datasets_hard/v_nets" \
#   solver.solver_name=grc_rank

# %%
# Run via your Virne entry point (e.g., main.py)
# ! python main.py solver.solver_name="" solver.sub_solver_name="ppo_gat_seq2seq+" training.num_train_epochs=200
! python main.py solver.solver_name="ppo_dual_gat+" solver.sub_solver_name="ppo_gat_seq2seq+" training.num_train_epochs=200

# --rl.pretrained_subsolver_model_path "path/to/your/pretrained_ra_model.pkl" \
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_sparse/tensor.py:5: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.4.4)
#   import scipy.sparse
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /content/drive/MyDrive/virne/main.py:12: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="settings", config_name="main")
# ...

# %%
# !ls /content/drive/MyDrive/virne/virne/solver/meta_heuristic

# %%
# ! python main.py solver.solver_name=fast_hpso system.if_time_window=True system.time_window_size=10 experiment.seed=42 experiment.if_load_p_net=False experiment.if_load_v_nets=False

# %%
# !python main.py \
#   experiment.seed=42 \
#   solver.solver_name=ga_meta \
#   experiment.save_root_dir="/content/drive/MyDrive/virne_output/results" \
#   p_net_setting.output.save_dir="/content/drive/MyDrive/virne_output/datasets/p_net" \
#   v_sim_setting.output.save_dir="/content/drive/MyDrive/virne_output/datasets/v_nets"
